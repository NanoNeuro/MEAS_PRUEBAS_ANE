# %%
import pandas as pd
import polars as pl
import numpy as np

import datetime as dt
import os

import sys

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from py_functions.MEAS_recordings import retrieve_peaks

# %% [markdown]
# ## Running cells

# %%
from nb_vars import FOLDER_INPUT_BASE, FOLDER_OUTPUT_BASE

# %% [markdown]
# **EXP1**

# %%
CONDITION_NAME = "EXPERIMENTO"
CONDITION = "1"

folder_input = f'{FOLDER_INPUT_BASE}/{CONDITION_NAME} {CONDITION}'
folder_output = f'{FOLDER_OUTPUT_BASE}/{CONDITION_NAME} {CONDITION}'

os.makedirs(folder_output, exist_ok=True)

list_conditions_exp_1 = [#('Condition', 'Time exp', 'Wells', 'Well_num', 'Replicate', 'Folder') 
                    ('H PLKO',       "Base",       ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.basal(000)'),
                    ('H PLKO',       "0 min",      ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(000)'),
                    ('H PLKO',       "10 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(001)'),
                    ('H PLKO',       "20 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(002)'),
                    ('H PLKO',       "30 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(003)'),
                    ('H PLKO',       "40 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(004)'),
                    ('H PLKO',       "50 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(005)'),  
                    ('H PLKO',       "60 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(006)'),
                    ('H PLKO',       "70 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(007)'),
                    ('H PLKO',       "80 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(008)'),
                    ('H PLKO',       "90 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(009)'),
                    ('H PLKO',       "100 min",    ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(010)'),  
                    ('H PLKO',       "110 min",    ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(011)'), 
                    ('H PLKO',       "120 min",    ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(012)'), 
                    ('H PLKO',       "130 min",    ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(013)'), 
                    ('H PLKO',       "140 min",    ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(014)'), 
                    ('H PLKO',       "150 min",    ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(015)'), 
                    ('H PLKO',       "160 min",    ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(016)'), 
                    ('H PLKO',       "170 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(017)'), 
                    ('H PLKO',       "24h + 0 min",      ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(000)'),
                    ('H PLKO',       "24h + 10 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(001)'),
                    ('H PLKO',       "24h + 20 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(002)'),
                    ('H PLKO',       "24h + 30 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(003)'),
                    ('H PLKO',       "24h + 40 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(004)'),
                    ('H PLKO',       "24h + 50 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(005)'),  
                    ('H PLKO',       "24h + 60 min",     ['B3', 'B5', 'C3', 'C5', 'D6'],  ['23', '25', '33', '35', '46'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(006)'),
                    ('H 219',        "Base",       ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.basal(000)'),
                    ('H 219',        "0 min",      ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(000)'),
                    ('H 219',        "10 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(001)'),
                    ('H 219',        "20 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(002)'),
                    ('H 219',        "30 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(003)'),
                    ('H 219',        "40 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(004)'),
                    ('H 219',        "50 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(005)'),
                    ('H 219',        "60 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(006)'),
                    ('H 219',        "70 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(007)'),
                    ('H 219',        "80 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(008)'),
                    ('H 219',        "90 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(009)'),
                    ('H 219',        "100 min",    ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(010)'),
                    ('H 219',        "110 min",    ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(011)'),
                    ('H 219',        "120 min",    ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(012)'),
                    ('H 219',        "130 min",    ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(013)'),
                    ('H 219',        "140 min",    ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(014)'),
                    ('H 219',        "150 min",    ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(015)'),
                    ('H 219',        "160 min",    ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(016)'),
                    ('H 219',        "170 min",    ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(017)'),
                    ('H 219',        "24h + 0 min",      ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(000)'),
                    ('H 219',        "24h + 10 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(001)'),
                    ('H 219',        "24h + 20 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(002)'),
                    ('H 219',        "24h + 30 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(003)'),
                    ('H 219',        "24h + 40 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(004)'),
                    ('H 219',        "24h + 50 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(005)'),
                    ('H 219',        "24h + 60 min",     ['A1', 'B2', 'C6', 'D2', 'D5'],  ['11', '22', '36', '42', '45'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(006)'),
                    ('LIPOS -',      "Base",       ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.basal(000)'),
                    ('LIPOS -',      "0 min",      ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(000)'),
                    ('LIPOS -',      "10 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(001)'),
                    ('LIPOS -',      "20 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(002)'),
                    ('LIPOS -',      "30 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(003)'),
                    ('LIPOS -',      "40 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(004)'),
                    ('LIPOS -',      "50 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(005)'),
                    ('LIPOS -',      "60 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(006)'),
                    ('LIPOS -',      "70 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(007)'),
                    ('LIPOS -',      "80 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(008)'),
                    ('LIPOS -',      "90 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(009)'),
                    ('LIPOS -',      "100 min",    ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(010)'),
                    ('LIPOS -',      "110 min",    ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(011)'),
                    ('LIPOS -',      "120 min",    ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(012)'),
                    ('LIPOS -',      "130 min",    ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(013)'),
                    ('LIPOS -',      "140 min",    ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(014)'),
                    ('LIPOS -',      "150 min",    ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(015)'),
                    ('LIPOS -',      "160 min",    ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(016)'),
                    ('LIPOS -',      "170 min",    ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(017)'),
                    ('LIPOS -',      "24h + 0 min",      ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(000)'),
                    ('LIPOS -',      "24h + 10 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(001)'),
                    ('LIPOS -',      "24h + 20 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(002)'),
                    ('LIPOS -',      "24h + 30 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(003)'),
                    ('LIPOS -',      "24h + 40 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(004)'),
                    ('LIPOS -',      "24h + 50 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(005)'),
                    ('LIPOS -',      "24h + 60 min",     ['A3', 'A4', 'A6', 'B6', 'D3'],  ['13', '14', '16', '26', '43'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(006)'),
                    ('LIPOS 219',    "Base",       ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.basal(000)'),
                    ('LIPOS 219',    "0 min",      ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(000)'),
                    ('LIPOS 219',    "10 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(001)'),
                    ('LIPOS 219',    "20 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(002)'),
                    ('LIPOS 219',    "30 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(003)'),
                    ('LIPOS 219',    "40 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(004)'),
                    ('LIPOS 219',    "50 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(005)'),
                    ('LIPOS 219',    "60 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(006)'),
                    ('LIPOS 219',    "70 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(007)'),
                    ('LIPOS 219',    "80 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(008)'),
                    ('LIPOS 219',    "90 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(009)'),
                    ('LIPOS 219',    "100 min",    ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(010)'),
                    ('LIPOS 219',    "110 min",    ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(011)'),
                    ('LIPOS 219',    "120 min",    ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(012)'),
                    ('LIPOS 219',    "130 min",    ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(013)'),
                    ('LIPOS 219',    "140 min",    ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(014)'),
                    ('LIPOS 219',    "150 min",    ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(015)'),
                    ('LIPOS 219',    "160 min",    ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(016)'),
                    ('LIPOS 219',    "170 min",    ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO(017)'),
                    ('LIPOS 219',    "24h + 0 min",      ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(000)'),
                    ('LIPOS 219',    "24h + 10 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(001)'),
                    ('LIPOS 219',    "24h + 20 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(002)'),
                    ('LIPOS 219',    "24h + 30 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(003)'),
                    ('LIPOS 219',    "24h + 40 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(004)'),
                    ('LIPOS 219',    "24h + 50 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(005)'),
                    ('LIPOS 219',    "24h + 60 min",     ['A5', 'B4', 'C1', 'C4', 'D1'],  ['15', '24', '31', '34', '41'],     [1, 2, 3, 4, 5],    'diaTRATAMIENTO.24h(006)'),
                   ]

# %%
print(f'OUTPUT: {folder_output}/df_peaks_full_{CONDITION_NAME}_{CONDITION}.csv')

list_df_peaks = []

for condition, time_exp, list_wells, list_wells_num, replicates, sample_base in list_conditions_exp_1:
    for well, well_num, replicate in zip(list_wells, list_wells_num, replicates):
        print(condition, time_exp, well, well_num, replicate, sample_base)
        list_peak_times, list_electrodes = retrieve_peaks(root=folder_input, sample_base=sample_base, well=(int(well_num[0]), int(well_num[1])))
        
        df_peaks_i = pl.DataFrame({'condition': [condition] * len(list_peak_times), 
                                    'time_exp': [time_exp] * len(list_peak_times), 
                                    'well': [well] * len(list_peak_times), 
                                    'well_num': [well_num] * len(list_peak_times), 
                                    'replicate': [replicate] * len(list_peak_times), 
                                    'electrode': list_electrodes, 
                                    'time': list_peak_times
                                    })
        
        list_df_peaks.append(df_peaks_i)

df_peaks_exp_1 = pl.concat(list_df_peaks)
df_peaks_exp_1.write_csv(f'{folder_output}/df_peaks_full_{CONDITION_NAME}_{CONDITION}.csv')

# %%
CONDITION_NAME = "CONTROL"
CONDITION_NAME_FOLDER = "EXPERIMENTO"
CONDITION = "1"

folder_input = f'{FOLDER_INPUT_BASE}/{CONDITION_NAME_FOLDER} {CONDITION}'
folder_output = f'{FOLDER_OUTPUT_BASE}/{CONDITION_NAME} {CONDITION}'

os.makedirs(folder_output, exist_ok=True)

list_conditions_control_1 = [#('Condition', 'Time exp', 'Wells', 'Well_num', 'Replicate', 'Folder') 
                    ('CONTROL',        "Base",         ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO.basal(000)'), 
                    ('CONTROL',        "0 min",        ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(000)'), 
                    ('CONTROL',        "10 min",       ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(001)'), 
                    ('CONTROL',        "20 min",       ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(002)'), 
                    ('CONTROL',        "30 min",       ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(003)'), 
                    ('CONTROL',        "40 min",       ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(004)'), 
                    ('CONTROL',        "50 min",       ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(005)'), 
                    ('CONTROL',        "60 min",       ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(006)'), 
                    ('CONTROL',        "70 min",       ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(007)'), 
                    ('CONTROL',        "80 min",       ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(008)'), 
                    ('CONTROL',        "90 min",       ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(009)'), 
                    ('CONTROL',        "100 min",      ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(010)'), 
                    ('CONTROL',        "110 min",      ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(011)'), 
                    ('CONTROL',        "120 min",      ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(012)'), 
                    ('CONTROL',        "130 min",      ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(013)'), 
                    ('CONTROL',        "140 min",      ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(014)'), 
                    ('CONTROL',        "150 min",      ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(015)'), 
                    ('CONTROL',        "160 min",      ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(016)'), 
                    ('CONTROL',        "170 min",      ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO(017)'), 
                    ('CONTROL',        "24h + 0 min",        ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO.24h(000)'),
                    ('CONTROL',        "24h + 10 min",        ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO.24h(001)'),
                    ('CONTROL',        "24h + 20 min",        ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO.24h(002)'),
                    ('CONTROL',        "24h + 30 min",        ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO.24h(003)'),
                    ('CONTROL',        "24h + 40 min",        ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO.24h(004)'),
                    ('CONTROL',        "24h + 50 min",        ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO.24h(005)'),
                    ('CONTROL',        "24h + 60 min",        ['A2', 'B1', 'C2', 'D4'],        ['12', '21', '32', '44'],           [1, 2, 3, 4],        'diaTRATAMIENTO.24h(006)'),
                   ]

# %%
print(f'OUTPUT: {folder_output}/df_peaks_full_{CONDITION_NAME}_{CONDITION}.csv')

list_df_peaks = []
for condition, time_exp, list_wells, list_wells_num, replicates, sample_base in list_conditions_control_1:
    for well, well_num, replicate in zip(list_wells, list_wells_num, replicates):
        print(condition, time_exp, well, well_num, replicate, sample_base)
        list_peak_times, list_electrodes = retrieve_peaks(root=folder_input, sample_base=sample_base, well=(int(well_num[0]), int(well_num[1])))
        
        df_peaks_i = pl.DataFrame({'condition': [condition] * len(list_peak_times), 
                                    'time_exp': [time_exp] * len(list_peak_times), 
                                    'well': [well] * len(list_peak_times), 
                                    'well_num': [well_num] * len(list_peak_times), 
                                    'replicate': [replicate] * len(list_peak_times), 
                                    'electrode': list_electrodes, 
                                    'time': list_peak_times
                                    })
        
        list_df_peaks.append(df_peaks_i)

df_peaks_ctrl_1 = pl.concat(list_df_peaks)
df_peaks_ctrl_1.write_csv(f'{folder_output}/df_peaks_full_{CONDITION_NAME}_{CONDITION}.csv')

# %%
CONDITION_NAME = "EXPERIMENTO"
CONDITION = "2"

folder_input = f'{FOLDER_INPUT_BASE}/{CONDITION_NAME} {CONDITION}'
folder_output = f'{FOLDER_OUTPUT_BASE}/{CONDITION_NAME} {CONDITION}'

os.makedirs(folder_output, exist_ok=True)

list_conditions_exp_2 = [#('Condition', 'Time exp', 'Wells', 'Well_num', 'Replicate', 'Folder') 
                    ('GLIO PLKO',        "Base",            ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_PRETRATAMIENTO(000)'),
                    ('GLIO PLKO',        "0 min",           ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(000)'),
                    ('GLIO PLKO',        "10 min",          ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(001)'),
                    ('GLIO PLKO',        "20 min",          ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(002)'),
                    ('GLIO PLKO',        "30 min",          ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(003)'),
                    ('GLIO PLKO',        "40 min",          ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(004)'),
                    ('GLIO PLKO',        "50 min",          ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(005)'),
                    ('GLIO PLKO',        "60 min",          ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(006)'),
                    ('GLIO PLKO',        "70 min",          ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(007)'),
                    ('GLIO PLKO',        "80 min",          ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(008)'),
                    ('GLIO PLKO',        "90 min",          ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(009)'),
                    ('GLIO PLKO',        "100 min",         ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(010)'),
                    ('GLIO PLKO',        "110 min",         ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(011)'),
                    ('GLIO PLKO',        "120 min",         ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(012)'),
                    ('GLIO PLKO',        "130 min",         ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(013)'),
                    ('GLIO PLKO',        "140 min",         ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(014)'),
                    ('GLIO PLKO',        "150 min",         ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(015)'),
                    ('GLIO PLKO',        "160 min",         ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(016)'),
                    ('GLIO PLKO',        "170 min",         ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(017)'),
                    ('GLIO PLKO',        "180 min",         ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(018)'),
                    ('GLIO PLKO',        "24h + 0 min",     ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(000)'),
                    ('GLIO PLKO',        "24h + 10 min",    ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(001)'),
                    ('GLIO PLKO',        "24h + 20 min",    ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(002)'),
                    ('GLIO PLKO',        "24h + 30 min",    ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(003)'),
                    ('GLIO PLKO',        "24h + 40 min",    ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(004)'),
                    ('GLIO PLKO',        "24h + 50 min",    ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(005)'),
                    ('GLIO PLKO',        "24h + 60 min",    ['A3', 'B6', 'C5', 'D1'],                    ['13', '26', '35', '41'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(006)'),
                    ('GLIO 219',         "Base",            ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_PRETRATAMIENTO(000)'),
                    ('GLIO 219',         "0 min",           ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(000)'),
                    ('GLIO 219',         "10 min",          ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(001)'),
                    ('GLIO 219',         "20 min",          ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(002)'),
                    ('GLIO 219',         "30 min",          ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(003)'),
                    ('GLIO 219',         "40 min",          ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(004)'),
                    ('GLIO 219',         "50 min",          ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(005)'),
                    ('GLIO 219',         "60 min",          ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(006)'),
                    ('GLIO 219',         "70 min",          ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(007)'),
                    ('GLIO 219',         "80 min",          ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(008)'),
                    ('GLIO 219',         "90 min",          ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(009)'),
                    ('GLIO 219',         "100 min",         ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(010)'),
                    ('GLIO 219',         "110 min",         ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(011)'),
                    ('GLIO 219',         "120 min",         ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(012)'),
                    ('GLIO 219',         "130 min",         ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(013)'),
                    ('GLIO 219',         "140 min",         ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(014)'),
                    ('GLIO 219',         "150 min",         ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(015)'),
                    ('GLIO 219',         "160 min",         ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(016)'),
                    ('GLIO 219',         "170 min",         ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(017)'),
                    ('GLIO 219',         "180 min",         ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(018)'),
                    ('GLIO 219',         "24h + 0 min",     ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(000)'),
                    ('GLIO 219',         "24h + 10 min",    ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(001)'),
                    ('GLIO 219',         "24h + 20 min",    ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(002)'),
                    ('GLIO 219',         "24h + 30 min",    ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(003)'),
                    ('GLIO 219',         "24h + 40 min",    ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(004)'),
                    ('GLIO 219',         "24h + 50 min",    ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(005)'),
                    ('GLIO 219',         "24h + 60 min",    ['A4', 'B5', 'C2', 'C3', 'D5'],              ['14', '25', '32', '33', '45'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(006)'),
                    ('LIPOS -',          "Base",            ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_PRETRATAMIENTO(000)'),
                    ('LIPOS -',          "0 min",           ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(000)'),
                    ('LIPOS -',          "10 min",          ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(001)'),
                    ('LIPOS -',          "20 min",          ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(002)'),
                    ('LIPOS -',          "30 min",          ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(003)'),
                    ('LIPOS -',          "40 min",          ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(004)'),
                    ('LIPOS -',          "50 min",          ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(005)'),
                    ('LIPOS -',          "60 min",          ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(006)'),
                    ('LIPOS -',          "70 min",          ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(007)'),
                    ('LIPOS -',          "80 min",          ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(008)'),
                    ('LIPOS -',          "90 min",          ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(009)'),
                    ('LIPOS -',          "100 min",         ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(010)'),
                    ('LIPOS -',          "110 min",         ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(011)'),
                    ('LIPOS -',          "120 min",         ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(012)'),
                    ('LIPOS -',          "130 min",         ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(013)'),
                    ('LIPOS -',          "140 min",         ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(014)'),
                    ('LIPOS -',          "150 min",         ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(015)'),
                    ('LIPOS -',          "160 min",         ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(016)'),
                    ('LIPOS -',          "170 min",         ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(017)'),
                    ('LIPOS -',          "180 min",         ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'DIA14.POSTSIEMBRA_TRATAMIENTO(018)'),
                    ('LIPOS -',          "24h + 0 min",     ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(000)'),
                    ('LIPOS -',          "24h + 10 min",    ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(001)'),
                    ('LIPOS -',          "24h + 20 min",    ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(002)'),
                    ('LIPOS -',          "24h + 30 min",    ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(003)'),
                    ('LIPOS -',          "24h + 40 min",    ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(004)'),
                    ('LIPOS -',          "24h + 50 min",    ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(005)'),
                    ('LIPOS -',          "24h + 60 min",    ['A2', 'B1', 'C1', 'C6', 'D4'],              ['12', '21', '31', '36', '44'],             [1, 2, 3, 4, 5],        'dia15.postsiembra_tratamientoplaca1.24h(006)'),
                    ('ASTRO 219',        "Base",            ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_PRETRATAMIENTO(000)'),
                    ('ASTRO 219',        "0 min",           ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(000)'),
                    ('ASTRO 219',        "10 min",          ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(001)'),
                    ('ASTRO 219',        "20 min",          ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(002)'),
                    ('ASTRO 219',        "30 min",          ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(003)'),
                    ('ASTRO 219',        "40 min",          ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(004)'),
                    ('ASTRO 219',        "50 min",          ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(005)'),
                    ('ASTRO 219',        "60 min",          ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(006)'),
                    ('ASTRO 219',        "70 min",          ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(007)'),
                    ('ASTRO 219',        "80 min",          ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(008)'),
                    ('ASTRO 219',        "90 min",          ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(009)'),
                    ('ASTRO 219',        "100 min",         ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(010)'),
                    ('ASTRO 219',        "110 min",         ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(011)'),
                    ('ASTRO 219',        "120 min",         ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(012)'),
                    ('ASTRO 219',        "130 min",         ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(013)'),
                    ('ASTRO 219',        "140 min",         ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(014)'),
                    ('ASTRO 219',        "150 min",         ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(015)'),
                    ('ASTRO 219',        "160 min",         ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(016)'),
                    ('ASTRO 219',        "170 min",         ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(017)'),
                    ('ASTRO 219',        "180 min",         ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'DIA14.POSTSIEMBRA_TRATAMIENTO(018)'),
                    ('ASTRO 219',        "24h + 0 min",     ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(000)'),
                    ('ASTRO 219',        "24h + 10 min",    ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(001)'),
                    ('ASTRO 219',        "24h + 20 min",    ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(002)'),
                    ('ASTRO 219',        "24h + 30 min",    ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(003)'),
                    ('ASTRO 219',        "24h + 40 min",    ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(004)'),
                    ('ASTRO 219',        "24h + 50 min",    ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(005)'),
                    ('ASTRO 219',        "24h + 60 min",    ['A1', 'A5', 'B4', 'D3'],                    ['11', '15', '24', '43'],                   [1, 2, 3, 4],           'dia15.postsiembra_tratamientoplaca1.24h(006)'),
                   ]

# %%
df_peaks_exp_2 = pd.DataFrame(columns=['condition', 'time_exp', 'well', 'well_num', 'replicate', 'electrode', 'time'])
print(f'OUTPUT: {folder_output}/df_peaks_full_{CONDITION_NAME}_{CONDITION}.csv')

list_df_peaks = []

for condition, time_exp, list_wells, list_wells_num, replicates, sample_base in list_conditions_exp_2:
    for well, well_num, replicate in zip(list_wells, list_wells_num, replicates):
        print(condition, time_exp, well, well_num, replicate, sample_base)
        list_peak_times, list_electrodes = retrieve_peaks(root=folder_input, sample_base=sample_base, well=(int(well_num[0]), int(well_num[1])))
        
        df_peaks_i = pl.DataFrame({'condition': [condition] * len(list_peak_times), 
                                    'time_exp': [time_exp] * len(list_peak_times), 
                                    'well': [well] * len(list_peak_times), 
                                    'well_num': [well_num] * len(list_peak_times), 
                                    'replicate': [replicate] * len(list_peak_times), 
                                    'electrode': list_electrodes, 
                                    'time': list_peak_times
                                    })
        
        list_df_peaks.append(df_peaks_i)

df_peaks_exp_2 = pl.concat(list_df_peaks)
df_peaks_exp_2.write_csv(f'{folder_output}/df_peaks_full_{CONDITION_NAME}_{CONDITION}.csv')

# %%
CONDITION_NAME = "CONTROL"
CONDITION_NAME_FOLDER = "EXPERIMENTO"
CONDITION = "2"

folder_input = f'{FOLDER_INPUT_BASE}/{CONDITION_NAME_FOLDER} {CONDITION}'
folder_output = f'{FOLDER_OUTPUT_BASE}/{CONDITION_NAME} {CONDITION}'


os.makedirs(folder_output, exist_ok=True)

list_conditions_control_2 = [#('Condition', 'Time exp', 'Wells', 'Well_num', 'Replicate', 'Folder') 
                    ('CONTROL',        "Base",         ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_PRETRATAMIENTO(000)'), 
                    ('CONTROL',        "0 min",        ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(000)'), 
                    ('CONTROL',        "10 min",       ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(001)'), 
                    ('CONTROL',        "20 min",       ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(002)'), 
                    ('CONTROL',        "30 min",       ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(003)'), 
                    ('CONTROL',        "40 min",       ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(004)'), 
                    ('CONTROL',        "50 min",       ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(005)'), 
                    ('CONTROL',        "60 min",       ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(006)'), 
                    ('CONTROL',        "70 min",       ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(007)'), 
                    ('CONTROL',        "80 min",       ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(008)'), 
                    ('CONTROL',        "90 min",       ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(009)'), 
                    ('CONTROL',        "100 min",      ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(010)'), 
                    ('CONTROL',        "110 min",      ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(011)'), 
                    ('CONTROL',        "120 min",      ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(012)'), 
                    ('CONTROL',        "130 min",      ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(013)'), 
                    ('CONTROL',        "140 min",      ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(014)'), 
                    ('CONTROL',        "150 min",      ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(015)'), 
                    ('CONTROL',        "160 min",      ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(016)'), 
                    ('CONTROL',        "170 min",      ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(017)'), 
                    ('CONTROL',        "180 min",      ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'DIA14.POSTSIEMBRA_TRATAMIENTO(018)'), 
                    ('CONTROL',        "24h + 0 min",         ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'dia15.postsiembra_tratamientoplaca1.24h(000)'), 
                    ('CONTROL',        "24h + 10 min",        ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'dia15.postsiembra_tratamientoplaca1.24h(001)'), 
                    ('CONTROL',        "24h + 20 min",        ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'dia15.postsiembra_tratamientoplaca1.24h(002)'), 
                    ('CONTROL',        "24h + 30 min",        ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'dia15.postsiembra_tratamientoplaca1.24h(003)'), 
                    ('CONTROL',        "24h + 40 min",        ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'dia15.postsiembra_tratamientoplaca1.24h(004)'), 
                    ('CONTROL',        "24h + 50 min",        ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'dia15.postsiembra_tratamientoplaca1.24h(005)'), 
                    ('CONTROL',        "24h + 60 min",        ['A6', 'B2', 'B3', 'C4', 'D2', 'D6'],        ['16', '22', '23', '34', '42', '46'],     [1, 2, 3, 4, 5, 6],  'dia15.postsiembra_tratamientoplaca1.24h(006)'), 
                   ]

# %%
df_peaks_ctrl_2 = pd.DataFrame(columns=['condition', 'time_exp', 'well', 'well_num', 'replicate', 'electrode', 'time'])
print(f'OUTPUT: {folder_output}/df_peaks_full_{CONDITION_NAME}_{CONDITION}.csv')

list_df_peaks = []

for condition, time_exp, list_wells, list_wells_num, replicates, sample_base in list_conditions_control_2:
    for well, well_num, replicate in zip(list_wells, list_wells_num, replicates):
        print(condition, time_exp, well, well_num, replicate, sample_base)
        list_peak_times, list_electrodes = retrieve_peaks(root=folder_input, sample_base=sample_base, well=(int(well_num[0]), int(well_num[1])))
        
        df_peaks_i = pl.DataFrame({'condition': [condition] * len(list_peak_times), 
                                    'time_exp': [time_exp] * len(list_peak_times), 
                                    'well': [well] * len(list_peak_times), 
                                    'well_num': [well_num] * len(list_peak_times), 
                                    'replicate': [replicate] * len(list_peak_times), 
                                    'electrode': list_electrodes, 
                                    'time': list_peak_times
                                    })
        
        list_df_peaks.append(df_peaks_i)


df_peaks_ctrl_2 = pl.concat(list_df_peaks)
df_peaks_ctrl_2.write_csv(f'{folder_output}/df_peaks_full_{CONDITION_NAME}_{CONDITION}.csv')

# %%
# !rm -rf $PWD/tmp
